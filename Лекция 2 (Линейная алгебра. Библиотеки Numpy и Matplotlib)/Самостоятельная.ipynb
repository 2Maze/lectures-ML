# %% [markdown]
# ## Задание 1
# Данны 2 набора данных. Нарисовать график рассеивания данных (пример на рисунке). Найти коофицент корреляции Пирсона (изображения с разными коофицентами кореляции ниже на рисунке).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# set seed
np.random.seed(42)

# Generate first dataset
X_1 = np.random.randint(low=-10, high=11, size=10)
y_1 = 2 * X_1 + np.random.randn(10)

# Generate seconda dataset
X_2 = np.random.randint(low=-10, high=11, size=10)
y_2 = np.cos(X_2) - 1.5 + np.random.randn(10)

# %% [markdown]
# ## Задание 2
# Реализовать класс перцептрона. Реализовать следующие методы: конструктор класса `__init__,`, метод `__call__` для принятие входных данных и выдачи ответов. Конструктор принимает количество входных признаков и инициализирует параметры модели случайным образом (не забывайте что смещение тоже параметр). Метод `__call__` принимает вектор признаков и вовращает на выход предсказанное значение.

# %%
class Perceptron(object):
  def __init__(self, in_features: int) -> None:
    # code here

  def __call__(self, x):
    # code here

# %%
# Out:
# 0

# %% [markdown]
# ## Задание 3
#
# Улучшить класс путём возможности выбора количества входных и выходных признаков (выходные признаки то же самое что количество нейронов). Так же смените функцию активации на softmax (на изображении).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Perceptron(object):
  def __init__(self, in_features: int, out_features: int) -> None:
    # code here

  def __call__(self, x):
    # code here
